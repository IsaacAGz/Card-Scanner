# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11s.pt")
model.train(data="card-detection.yaml", epochs=100, imgsz=640)

# %%
metrics = model.val()
#results = model.("image/path")

# %%
success = model.export(format="onnx")
